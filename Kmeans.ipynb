# %% [markdown]
# <a href="https://colab.research.google.com/github/CajunCompiler/SYBCA-SEM4/blob/main/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X = np.array([
    [2, 10],
    [2, 5],
    [8, 4],
    [7, 5],
    [6, 4],
    [1, 2],
    [4, 9]
])

labels_names = [f"P{i}" for i in range(len(X))]

# %%
# 2.Apply K Mean
k = 3
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
labels = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

# %%
#3.Visualization
plt.figure(figsize=(7,6))
plt.scatter(
    x[:,0], x[:,1],
    c=labels,
    cmap="viridis",
    s=100
)

# %%
plt.figure(figsize=(7, 6))

# Scatter plot of data points
plt.scatter(
    X[:, 0], X[:, 1],
    c=labels,
    cmap="viridis",
    s=100
)

# Annotate each point
for i, txt in enumerate(labels_names):
    plt.annotate(
        txt,
        (X[i, 0] + 0.1, X[i, 1] + 0.1),
        fontsize=9
    )

# Plot centroids
plt.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c="red",
    marker="X",
    s=250,
    label="Centroids"
)

plt.title("K-Means Clustering (k=3)")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()
